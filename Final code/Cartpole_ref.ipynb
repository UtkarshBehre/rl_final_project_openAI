# %% [markdown]
# # Run cartpole agent file

# %%
# %run cartpole_agent.py
import matplotlib.pyplot as plt

# defining a graph plotting helper method
def plot_graph(xlab, ylab, values, title, takeMean):
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    plt.title(title)
    plt.grid(True)
    # plots the mean of the next 10 rewards at every episode
    if takeMean:
        window_range = 10
        plt.plot([np.mean(values[ind-window_range: ind]) for ind in range(window_range, len(values))])
    else:
        plt.plot(values)

total_episodes = 19000
epsilon_decay = 0.9998
render_while_training = False
render_while_testing = False
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # DQN on CartPole-v1

# %%
dqn_agent1 = Agent_CartPole(version=1, ddqn=False)
# Out:
# /Users/utkarsh/opt/anaconda3/lib/python3.7/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
dqn_agent1.train_agent(episodes_total=total_episodes, epsilon_decay = epsilon_decay, render = render_while_training)
# Out:
# Episode: 19000/19000 | Epsilon: 0.02241 | Reward: 137
# Model has finished training. Use test_agent() function to test.

# %%
dqn_agent1.test_agent(render = render_while_testing)
# Out:
# Run: 0 | Reward: 500
# Run: 1 | Reward: 500
# Run: 2 | Reward: 500
# Run: 3 | Reward: 500
# Run: 4 | Reward: 500
# Run: 5 | Reward: 500
# Run: 6 | Reward: 500
# Run: 7 | Reward: 500
# Run: 8 | Reward: 500
# Run: 9 | Reward: 500
# Run: 10 | Reward: 500
# Run: 11 | Reward: 500
# Run: 12 | Reward: 500
# Run: 13 | Reward: 500
# Run: 14 | Reward: 500
# Run: 15 | Reward: 500
# Run: 16 | Reward: 500
# Run: 17 | Reward: 500
# Run: 18 | Reward: 500
# Run: 19 | Reward: 500
# Run: 20 | Reward: 500
# Run: 21 | Reward: 500
# Run: 22 | Reward: 500
# Run: 23 | Reward: 500
# Run: 24 | Reward: 500
# Run: 25 | Reward: 500
# Run: 26 | Reward: 500
# Run: 27 | Reward: 500
# Run: 28 | Reward: 500
# Run: 29 | Reward: 500
# Run: 30 | Reward: 500
# Best Score out of 30 runs: 500

# %%
plot_graph("episodes", "rewards", dqn_agent1.hist_rewards, "Rewards vs Episodes", takeMean=True)

# %%
plot_graph("episodes", "epsilon", dqn_agent1.hist_epsilon_values, "Epsilon Values vs Episodes", takeMean=False)

# %% [markdown]
# # Double DQN on CartPole-v1

# %%
ddqn_agent1 = Agent_CartPole(version=1, ddqn=True)

# %%
ddqn_agent1.train_agent(episodes_total=total_episodes, epsilon_decay = epsilon_decay, render = render_while_training)
# Out:
# Episode: 19000/19000 | Epsilon: 0.02241 | Reward: 500
# Model has finished training. Use test_agent() function to test.

# %%
ddqn_agent1.test_agent(render = render_while_testing)
# Out:
# Run: 0 | Reward: 500
# Run: 1 | Reward: 500
# Run: 2 | Reward: 500
# Run: 3 | Reward: 500
# Run: 4 | Reward: 500
# Run: 5 | Reward: 500
# Run: 6 | Reward: 500
# Run: 7 | Reward: 500
# Run: 8 | Reward: 500
# Run: 9 | Reward: 500
# Run: 10 | Reward: 500
# Run: 11 | Reward: 500
# Run: 12 | Reward: 500
# Run: 13 | Reward: 500
# Run: 14 | Reward: 500
# Run: 15 | Reward: 500
# Run: 16 | Reward: 500
# Run: 17 | Reward: 500
# Run: 18 | Reward: 500
# Run: 19 | Reward: 500
# Run: 20 | Reward: 500
# Run: 21 | Reward: 500
# Run: 22 | Reward: 500
# Run: 23 | Reward: 500
# Run: 24 | Reward: 500
# Run: 25 | Reward: 500
# Run: 26 | Reward: 500
# Run: 27 | Reward: 500
# Run: 28 | Reward: 500
# Run: 29 | Reward: 500
# Run: 30 | Reward: 500
# Best Score out of 30 runs: 500

# %%
plot_graph("episodes", "rewards", ddqn_agent1.hist_rewards, "Rewards vs Episodes", takeMean=True)

# %%
plot_graph("episodes", "epsilon", ddqn_agent1.hist_epsilon_values, "Epsilon Values vs Episodes", takeMean=False)

# %% [markdown]
# # DQN on CartPole-v0

# %%
dqn_agent0 = Agent_CartPole(version=0, ddqn=False)

# %%
dqn_agent0.train_agent(episodes_total=17500, epsilon_decay = epsilon_decay, render = render_while_training)
# Out:
# Episode: 17500/17500 | Epsilon: 0.03025 | Reward: 200
# Model has finished training. Use test_agent() function to test.

# %%
dqn_agent0.test_agent(render = render_while_testing)
# Out:
# Run: 0 | Reward: 174
# Run: 1 | Reward: 176
# Run: 2 | Reward: 162
# Run: 3 | Reward: 168
# Run: 4 | Reward: 177
# Run: 5 | Reward: 196
# Run: 6 | Reward: 189
# Run: 7 | Reward: 200
# Run: 8 | Reward: 174
# Run: 9 | Reward: 200
# Run: 10 | Reward: 200
# Run: 11 | Reward: 173
# Run: 12 | Reward: 188
# Run: 13 | Reward: 196
# Run: 14 | Reward: 169
# Run: 15 | Reward: 180
# Run: 16 | Reward: 172
# Run: 17 | Reward: 177
# Run: 18 | Reward: 177
# Run: 19 | Reward: 172
# Run: 20 | Reward: 191
# Run: 21 | Reward: 184
# Run: 22 | Reward: 177
# Run: 23 | Reward: 200
# Run: 24 | Reward: 188
# Run: 25 | Reward: 185
# Run: 26 | Reward: 176
# Run: 27 | Reward: 168
# Run: 28 | Reward: 165
# Run: 29 | Reward: 200
# Run: 30 | Reward: 198
# Best Score out of 30 runs: 200

# %%
plot_graph("episodes", "rewards", dqn_agent0.hist_rewards, "Rewards vs Episodes", takeMean=True)

# %%
plot_graph("episodes", "epsilon", dqn_agent0.hist_epsilon_values, "Epsilon Values vs Episodes", takeMean=False)

# %% [markdown]
# # Double DQN on CartPole-v0

# %%
ddqn_agent0 = Agent_CartPole(version=0, ddqn=True)

# %%
ddqn_agent0.train_agent(episodes_total=17500, epsilon_decay = epsilon_decay, render = render_while_training)

# %%
ddqn_agent0.test_agent(render = render_while_testing)

# %%
plot_graph("episodes", "rewards", ddqn_agent0.hist_rewards, "Rewards vs Episodes", takeMean=True)

# %%
plot_graph("episodes", "epsilon", ddqn_agent0.hist_epsilon_values, "Epsilon Values vs Episodes", takeMean=False)
